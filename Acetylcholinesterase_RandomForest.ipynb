# %% [markdown]
# <a href="https://colab.research.google.com/github/kaustubhadixit/BioInformatics/blob/DrugDiscovery/Acetylcholinesterase_RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **The goal of our model building is we want to see which functional group or fingerprints are essential for designing a good drug or a potent one.**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/data/acetylcholinesterase_dataset_for_model.csv")
df
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0              1           1           1  ...             0             0  6.124939
# 1              1           1           1  ...             0             0  7.000000
# 2              1           1           1  ...             0             0  4.301030
# 3              1           1           0  ...             0             0  6.522879
# 4              1           1           0  ...             0             0  6.096910
# ...          ...         ...         ...  ...           ...           ...       ...
# 4690           1           1           1  ...             0             0  5.612610
# 4691           1           1           1  ...             0             0  5.595166
# 4692           1           1           1  ...             0             0  5.419075
# 4693           1           1           1  ...             0             0  5.460924
# ...

# %% [markdown]
# **Features**

# %%
# Input Feature
X = df.drop('pIC50', axis=1)
X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 4690           1           1  ...             0             0
# 4691           1           1  ...             0             0
# 4692           1           1  ...             0             0
# 4693           1           1  ...             0             0
# 4694           1           1  ...             0             0
#
# [4695 rows x 881 columns]

# %%
# Output Feature
Y = df["pIC50"]
Y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 4690    5.612610
# 4691    5.595166
# 4692    5.419075
# 4693    5.460924
# 4694    5.555955
# Name: pIC50, Length: 4695, dtype: float64

# %% [markdown]
# **Removing Features with low variance**

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.85 * (1 - .85)))    
x = selection.fit_transform(X)

# %%
x.shape
# Out:
# (4695, 173)

# %% [markdown]
# **Test Train Split 70/30**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((3286, 881), (3286,), (1409, 881), (1409,))

# %%
x_train, x_test, y_train, y_test = train_test_split(x, Y, test_size=0.3)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((3286, 173), (3286,), (1409, 173), (1409,))

# %% [markdown]
# ### **Random Forest Regression model**

# %%
# Low variance features not removed
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
S = model.score(X_test, Y_test)
S
# Out:
# 0.5176546182340747

# %%
# Low varinace features removed
model2 = RandomForestRegressor(n_estimators=150)
model2.fit(x_train, y_train)
s = model2.score(x_test, y_test)
s
# Out:
# 0.535174796368816

# %%
Y_pred = model.predict(X_test)

# %%
y_pred = model2.predict(x_test)

# %% [markdown]
# ## **Scatter Plot of Experimental vs Predicted pIC50 Values**

# %% [markdown]
# **Without reomoving low variance features**

# %%
sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(Y_test, Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5.5, 5.5)
plt.show
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.show>

# %% [markdown]
# **After reomoving low variance features**

# %%
sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(y_test, y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(6, 6)
plt.show
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.show>
