# %% [markdown]
# <a href="https://colab.research.google.com/github/kaustubhadixit/BioInformatics/blob/DrugDiscovery/Acetylcholinesterase_PaDELdescriptors_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Download PaDEL-Descriptor**

# %%
! wget https://github.com/kaustubhadixit/BioInformatics/raw/main/padel.zip
! wget https://github.com/kaustubhadixit/BioInformatics/raw/main/padel.sh
# Out:
# --2021-01-07 14:54:12--  https://github.com/kaustubhadixit/BioInformatics/raw/main/padel.zip
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/kaustubhadixit/BioInformatics/main/padel.zip [following]
# --2021-01-07 14:54:13--  https://raw.githubusercontent.com/kaustubhadixit/BioInformatics/main/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M  85.7MB/s    in 0.3s
#
# 2021-01-07 14:54:14 (85.7 MB/s) - ‘padel.zip’ saved [25768637/25768637]
#
# ...

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !ls
# Out:
# gdrive	__MACOSX  PaDEL-Descriptor  padel.sh  padel.zip  sample_data

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/data/acetylcholinesterase_04_bioactivity_data_pIC50.csv')
df
# Out:
#       Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0              0       CHEMBL133897  ...           6.0  6.124939
# 1              1       CHEMBL336398  ...           5.0  7.000000
# 2              2       CHEMBL131588  ...           5.0  4.301030
# 3              3       CHEMBL130628  ...           5.0  6.522879
# 4              4       CHEMBL130478  ...           6.0  6.096910
# ...          ...                ...  ...           ...       ...
# 4690        4690      CHEMBL4293155  ...           3.0  5.612610
# 4691        4691      CHEMBL4282558  ...           3.0  5.595166
# 4692        4692      CHEMBL4281727  ...           3.0  5.419075
# 4693        4693      CHEMBL4292349  ...           5.0  5.460924
# 4694        4694      CHEMBL4278260  ...           4.0  5.555955
#
# [4695 rows x 9 columns]

# %%
useful_list = ['canonical_smiles','molecule_chembl_id']
df_useful = df[useful_list]
df_useful
# Out:
#                                        canonical_smiles molecule_chembl_id
# 0                 CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1       CHEMBL133897
# 1            O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1       CHEMBL336398
# 2     CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1       CHEMBL131588
# 3         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F       CHEMBL130628
# 4             CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C       CHEMBL130478
# ...                                                 ...                ...
# 4690  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccccc3Cl)CC...      CHEMBL4293155
# 4691  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3cccc(Cl)c3)...      CHEMBL4282558
# 4692  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccc(Br)cc3)...      CHEMBL4281727
# 4693  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3cccc([N+](=...      CHEMBL4292349
# 4694  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccc(C#N)cc3...      CHEMBL4278260
#
# [4695 rows x 2 columns]

# %%
df_useful.to_csv('molecule.smi', index=False, sep='\t', header=False)

# %%
! cat molecule.smi | head
# Out:
# CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1	CHEMBL133897
# O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1	CHEMBL336398
# CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1	CHEMBL131588
# O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F	CHEMBL130628
# CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C	CHEMBL130478
# CSc1nc(-c2ccc(C)cc2)nn1C(=O)N(C)c1ccccc1	CHEMBL130112
# CSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N(C)C	CHEMBL130098
# CCCCCCSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N1CCOCC1	CHEMBL337486
# COc1ccc(-c2nc(SC)n(C(=O)N(C)C)n2)cc1	CHEMBL336538
# CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)c1ccccc1	CHEMBL131051

# %% [markdown]
# ## **Calculate PaDEL descriptors**

# %%
! bash padel.sh

# %%
! cp "/content/descriptors_output.csv" "/content/gdrive/My Drive/Colab Notebooks/data"

# %% [markdown]
# ## **Preparing the X and Y Data Matrices**

# %% [markdown]
# **X Matrix**

# %%
df_x = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/data/descriptors_output.csv')

# %%
df_x
# Out:
#                Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0      CHEMBL133897           1  ...             0             0
# 1      CHEMBL336398           1  ...             0             0
# 2      CHEMBL130628           1  ...             0             0
# 3      CHEMBL131588           1  ...             0             0
# 4      CHEMBL130478           1  ...             0             0
# ...             ...         ...  ...           ...           ...
# 4690  CHEMBL4293155           1  ...             0             0
# 4691  CHEMBL4282558           1  ...             0             0
# 4692  CHEMBL4292349           1  ...             0             0
# 4693  CHEMBL4281727           1  ...             0             0
# 4694  CHEMBL4278260           1  ...             0             0
#
# [4695 rows x 882 columns]

# %%
df_x = df_x.drop(columns=['Name'])
df_x
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 4690           1           1  ...             0             0
# 4691           1           1  ...             0             0
# 4692           1           1  ...             0             0
# 4693           1           1  ...             0             0
# 4694           1           1  ...             0             0
#
# [4695 rows x 881 columns]

# %% [markdown]
# **Y Variable**
#
# Converting IC50 to pIC50

# %%
df_y = df['pIC50']
df_y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 4690    5.612610
# 4691    5.595166
# 4692    5.419075
# 4693    5.460924
# 4694    5.555955
# Name: pIC50, Length: 4695, dtype: float64

# %%
DF = pd.concat([df_x,df_y], axis=1)
DF
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0              1           1           1  ...             0             0  6.124939
# 1              1           1           1  ...             0             0  7.000000
# 2              1           1           1  ...             0             0  4.301030
# 3              1           1           0  ...             0             0  6.522879
# 4              1           1           0  ...             0             0  6.096910
# ...          ...         ...         ...  ...           ...           ...       ...
# 4690           1           1           1  ...             0             0  5.612610
# 4691           1           1           1  ...             0             0  5.595166
# 4692           1           1           1  ...             0             0  5.419075
# 4693           1           1           1  ...             0             0  5.460924
# ...

# %%
DF.to_csv('acetylcholinesterase_dataset_for_model.csv', index=False)

# %%
# !cp "/content/acetylcholinesterase_dataset_for_model" "/content/gdrive/My Drive/Colab Notebooks/data"
